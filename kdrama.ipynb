# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-679a21bd-59a0-429b-9847-c0e5e5fc971c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-679a21bd-59a0-429b-9847-c0e5e5fc971c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('kdrama (1).csv')

# %%
df.tail(5)
# Out:
#                        Name                   Aired Date  Year of release  \
# 245    Live Up to Your Name   Aug 12, 2017 - Oct 1, 2017             2017
# 246    Queen for Seven Days   May 31, 2017 - Aug 3, 2017             2017
# 247                  Memory   Mar 18, 2016 - May 7, 2016             2016
# 248        A Korean Odyssey   Dec 23, 2017 - Mar 4, 2018             2017
# 249  Voice 4: Judgment Hour  Jun 18, 2021 - Jul 31, 2021             2021
#
#     Original Network             Aired On  Number of Episodes       Duration  \
# 245              tvN     Saturday, Sunday                  16  1 hr. 10 min.
# 246             KBS2  Wednesday, Thursday                  20        60 min.
# 247              tvN     Friday, Saturday                  16   1 hr. 5 min.
# 248     Netflix, tvN     Saturday, Sunday                  20  1 hr. 20 min.
# 249              tvN     Friday, Saturday                  14   1 hr. 3 min.
#
#               Content Rating  Rating  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Name', 'Aired Date', 'Year of release', 'Original Network', 'Aired On',
#        'Number of Episodes', 'Duration', 'Content Rating', 'Rating',
#        'Synopsis', 'Genre', 'Tags', 'Director', 'Screenwriter', 'Cast',
#        'Production companies', 'Rank'],
#       dtype='object')

# %%
print(df['Name'][35:41])
# Out:
# 35             Taxi Driver
# 36            Life on Mars
# 37             Beyond Evil
# 38             Racket Boys
# 39    Hometown Cha-Cha-Cha
# 40      Six Flying Dragons
# Name: Name, dtype: object

# %%
print(df[['Name','Aired On']])
# Out:
#                        Name              Aired On
# 0            Move to Heaven                Friday
# 1            Flower of Evil   Wednesday, Thursday
# 2         Hospital Playlist              Thursday
# 3       Hospital Playlist 2              Thursday
# 4                 My Mister   Wednesday, Thursday
# ..                      ...                   ...
# 245    Live Up to Your Name      Saturday, Sunday
# 246    Queen for Seven Days   Wednesday, Thursday
# 247                  Memory      Friday, Saturday
# 248        A Korean Odyssey      Saturday, Sunday
# 249  Voice 4: Judgment Hour      Friday, Saturday
#
# [250 rows x 2 columns]

# %%
print(df.iloc[248,0])
# Out:
# A Korean Odyssey

# %%
print(df.iloc[120:125])
# Out:
#                          Name                   Aired Date  Year of release  \
# 120      Thirty But Seventeen  Jul 23, 2018 - Sep 18, 2018             2018
# 121  When the Camellia Blooms  Sep 18, 2019 - Nov 21, 2019             2019
# 122           Be Melodramatic   Aug 9, 2019 - Sep 28, 2019             2019
# 123             Itaewon Class  Jan 31, 2020 - Mar 21, 2020             2020
# 124                  Snowdrop  Dec 18, 2021 - Jan 30, 2022             2021
#
#     Original Network              Aired On  Number of Episodes       Duration  \
# 120              SBS       Monday, Tuesday                  32        35 min.
# 121  KBS2,  Netflix    Wednesday, Thursday                  40        35 min.
# 122       jTBC, Viki      Friday, Saturday                  16   1 hr. 5 min.
# 123    jTBC, Netflix      Friday, Saturday                  16  1 hr. 10 min.
# 124             jTBC      Saturday, Sunday                  16  1 hr. 30 min.
#
#               Content Rating  Rating  \
# ...

# %%
for index,row in df.iterrows():
  if 'Crash Landing on You' in row['Name']:
    print(row['Year of release'])
# Out:
# 2019

# %%
for index,row in df.iterrows():
  print(index,row['Name'])
# Out:
# 0 Move to Heaven
# 1 Flower of Evil
# 2 Hospital Playlist
# 3 Hospital Playlist 2
# 4 My Mister
# 5 Reply 1988
# 6 Weak Hero Class 1
# 7 Prison Playbook
# 8 Alchemy of Souls
# 9 Extraordinary Attorney Woo
# 10 Mr. Queen
# 11 Mother
# 12 It's Okay to Not Be Okay
# 13 Crash Landing on You
# 14 Vincenzo
# 15 Navillera
# 16 Signal
# 17 Mr. Sunshine
# 18 Happiness
# 19 Kingdom: Season 2
# 20 SKY Castle
# 21 Tomorrow
# 22 Healer
# 23 Stranger
# 24 Twenty-Five Twenty-One
# 25 The Red Sleeve
# 26 Goblin
# 27 The Uncanny Counter
# 28 Mouse
# 29 Kingdom
# 30 Weightlifting Fairy Kim Bok Joo
# 31 D.P.
# 32 The Devil Judge
# 33 The Penthouse
# 34 Youth of May
# 35 Taxi Driver
# 36 Life on Mars
# 37 Beyond Evil
# 38 Racket Boys
# 39 Hometown Cha-Cha-Cha
# 40 Six Flying Dragons
# 41 Our Beloved Summer
# 42 The Guest
# 43 Dear My Friends
# 44 While You Were Sleeping
# 45 The Penthouse 2
# 46 Chicago Typewriter
# 47 18 Again
# 48 Arthdal Chronicles Part 2
# 49 Arthdal Chronicles Part 3
# ...

# %%
df.loc[df['Year of release']==2020]
# Out:
#                                      Name                   Aired Date  \
# 1                          Flower of Evil  Jul 29, 2020 - Sep 23, 2020
# 2                       Hospital Playlist  Mar 12, 2020 - May 28, 2020
# 10                              Mr. Queen  Dec 12, 2020 - Feb 14, 2021
# 12               It's Okay to Not Be Okay  Jun 20, 2020 - Aug  9, 2020
# 19                      Kingdom: Season 2                 Mar 13, 2020
# 27                    The Uncanny Counter  Nov 28, 2020 - Jan 24, 2021
# 33                          The Penthouse  Oct 26, 2020 - Jan  5, 2021
# 47                               18 Again  Sep 21, 2020 - Nov 10, 2020
# 51                         Dr. Romantic 2  Jan  6, 2020 - Feb 25, 2020
# 54                             Sweet Home                 Dec 18, 2020
# 85                             Once Again  Mar 28, 2020 - Sep 13, 2020
# 86                                Missing  Aug 29, 2020 - Oct 11, 2020
# ...

# %%
df.loc[df['Rating']==9.0,'Name']
# Out:
# 8               Alchemy of Souls
# 9     Extraordinary Attorney Woo
# 10                     Mr. Queen
# 11                        Mother
# 12      It's Okay to Not Be Okay
# 13          Crash Landing on You
# 14                      Vincenzo
# 15                     Navillera
# 16                        Signal
# Name: Name, dtype: object

# %%
df.loc[(df['Year of release']==2021) & (df['Number of Episodes']==20)]
# Out:
#                      Name                   Aired Date  Year of release  \
# 14               Vincenzo  Feb 20, 2021 - May  2, 2021             2021
# 28                  Mouse  Mar  3, 2021 - May 19, 2021             2021
# 237  The King's Affection  Oct 11, 2021 - Dec 14, 2021             2021
#
#     Original Network              Aired On  Number of Episodes       Duration  \
# 14    Netflix,  tvN       Saturday, Sunday                  20  1 hr. 25 min.
# 28               tvN   Wednesday, Thursday                  20  1 hr. 15 min.
# 237    KBS2, Netflix       Monday, Tuesday                  20  1 hr. 10 min.
#
#                             Content Rating  Rating  \
# 14                 15+ - Teens 15 or older     9.0
# 28   18+ Restricted (violence & profanity)     8.7
# 237                15+ - Teens 15 or older     8.3
#
#                                               Synopsis  \
# 14   At the age of eight, Park Joo Hyeong went to I...
# ...

# %%
df.loc[df['Name'].str.contains('You[a-z]*')]
# Out:
#                              Name                   Aired Date  \
# 13           Crash Landing on You  Dec 14, 2019 - Feb 16, 2020
# 34                   Youth of May  May  3, 2021 - Jun  8, 2021
# 44        While You Were Sleeping  Sep 27, 2017 - Nov 16, 2017
# 93                   Age of Youth  Jul 22, 2016 - Aug 27, 2016
# 106             I Hear Your Voice  Jun  5, 2013 - Aug  1, 2013
# 141           If You Wish Upon Me  Aug 10, 2022 - Sep 29, 2022
# 145          Doom at Your Service  May 10, 2021 - Jun 29, 2021
# 157             Extraordinary You   Oct 2, 2019 - Nov 21, 2019
# 163                Age of Youth 2   Aug 25, 2017 - Oct 7, 2017
# 170       Sell Your Haunted House   Apr 14, 2021 - Jun 9, 2021
# 197       The Sound of Your Heart   Nov 7, 2016 - Nov 28, 2016
# 210            Are You Human Too?    Jun 4, 2018 - Aug 7, 2018
# 212  The Smile Has Left Your Eyes   Oct 3, 2018 - Nov 22, 2018
# 217              Touch Your Heart   Feb 6, 2019 - Mar 28, 2019
# ...

# %%
df.loc[df['Name'].str.contains('^You[a-z]*')]
# Out:
#             Name                   Aired Date  Year of release  \
# 34  Youth of May  May  3, 2021 - Jun  8, 2021             2021
#
#    Original Network          Aired On  Number of Episodes       Duration  \
# 34             KBS2   Monday, Tuesday                  12  1 hr. 10 min.
#
#              Content Rating  Rating  \
# 34  15+ - Teens 15 or older     8.8
#
#                                              Synopsis  \
# 34  Hee Tae becomes the pride of Gwangju when he e...
#
#                                         Genre  \
# 34  Historical,  Romance,  Drama,  Melodrama
#
#                                                  Tags  \
# 34  1980s, Nurse, Rich Man/Poor Woman, Gwangju Upr...
#
#                         Director Screenwriter  \
# 34  Song Min Yeop, Lee Dae Kyung     Lee Kang
#
#                                                  Cast  \
# 34  Lee Do Hyun, Go Min Si, Lee Sang Yi, Geum Sae ...
#
#        Production companies Rank
# 34  Story Hunter Production  #35

# %%
#df.sort_values(by='Rating', ascending=False)
#df.isnull().sum()          # Check missing values
#df.dropna()                # Drop missing rows
#df.fillna('Unknown')       # Fill missing values
#df['Genre'].value_counts()
#df['Year of release'].unique()
#df.groupby('Year of release')['Rating'].mean()
#df['Rating x Episodes'] = df['Rating'] * df['Number of Episodes']
#print(df['Rating x Episodes']) or can print by for loop:
#for index, row in df.iloc[1:11].iterrows():
    #print(row['Name'], row['Rating x Episodes'])
# Out:
# Flower of Evil 145.6
# Hospital Playlist 109.19999999999999
# Hospital Playlist 2 109.19999999999999
# My Mister 145.6
# Reply 1988 182.0
# Weak Hero Class 1 72.8
# Prison Playbook 145.6
# Alchemy of Souls 180.0
# Extraordinary Attorney Woo 144.0
# Mr. Queen 180.0

# %%
df.rename(columns={'Name': 'Drama Name'}, inplace=True)

# %%
df.query("`Rating` > 8.5 and `Year of release` == 2021")
# Out:
#               Drama Name                   Aired Date  Year of release  \
# 0         Move to Heaven                 May 14, 2021             2021
# 3    Hospital Playlist 2  Jun 17, 2021 - Sep 16, 2021             2021
# 14              Vincenzo  Feb 20, 2021 - May  2, 2021             2021
# 15             Navillera  Mar 22, 2021 - Apr 27, 2021             2021
# 18             Happiness  Nov  5, 2021 - Dec 11, 2021             2021
# 25        The Red Sleeve   Nov 12, 2021 - Jan 1, 2022             2021
# 28                 Mouse  Mar  3, 2021 - May 19, 2021             2021
# 31                  D.P.                 Aug 27, 2021             2021
# 32       The Devil Judge  Jul  3, 2021 - Aug 22, 2021             2021
# 34          Youth of May  May  3, 2021 - Jun  8, 2021             2021
# 35           Taxi Driver  Apr  9, 2021 - May 29, 2021             2021
# 37           Beyond Evil  Feb 19, 2021 - Apr 10, 2021             2021
# ...

# %%
df['Drama Name'] = df['Drama Name'].str.strip().str.upper()
print(df['Drama Name'])
# Out:
# 0              MOVE TO HEAVEN
# 1              FLOWER OF EVIL
# 2           HOSPITAL PLAYLIST
# 3         HOSPITAL PLAYLIST 2
# 4                   MY MISTER
#                 ...
# 245      LIVE UP TO YOUR NAME
# 246      QUEEN FOR SEVEN DAYS
# 247                    MEMORY
# 248          A KOREAN ODYSSEY
# 249    VOICE 4: JUDGMENT HOUR
# Name: Drama Name, Length: 250, dtype: object

# %%
df['Drama Name Length'] = df['Drama Name'].apply(len)
print(df['Drama Name Length'])
# Out:
# 0      14
# 1      14
# 2      17
# 3      19
# 4       9
#        ..
# 245    20
# 246    20
# 247     6
# 248    16
# 249    22
# Name: Drama Name Length, Length: 250, dtype: int64
