# %%
from google.colab import files
files.upload();
# Out:
#      <input type="file" id="files-e23625e0-c632-4936-beca-5b250a47d2c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e23625e0-c632-4936-beca-5b250a47d2c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
for index,rows in df.iterrows():
  print(index,rows['Name']);
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.loc[df['Attack']==49]
# Out:
#        #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1  Bulbasaur  Grass  Poison  45      49       49       65       65
# 166  152  Chikorita  Grass     NaN  45      49       65       49       65
# 506  456    Finneon  Water     NaN  49      49       56       49       61
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 166     45           2      False
# 506     66           4      False

# %%
df.sort_values(['Speed'],ascending=True)
# Out:
#        #                       Name   Type 1  Type 2   HP  Attack  Defense  \
# 495  446                   Munchlax   Normal     NaN  135      85       40
# 230  213                    Shuckle      Bug    Rock   20      10      230
# 359  328                   Trapinch   Ground     NaN   45     100       45
# 486  438                     Bonsly     Rock     NaN   50      80       95
# 658  597                  Ferroseed    Grass   Steel   44      50       91
# ..   ...                        ...      ...     ...  ...     ...      ...
# 428  386         DeoxysNormal Forme  Psychic     NaN   50     150       50
# 154  142  AerodactylMega Aerodactyl     Rock  Flying   80     135       85
# 429  386         DeoxysAttack Forme  Psychic     NaN   50     180       20
# 315  291                    Ninjask      Bug  Flying   61      90       45
# 431  386          DeoxysSpeed Forme  Psychic     NaN   50      95       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#First it will sort by the "Type 1" column
#If there are ties (same "Type 1" values), it will sort those tied rows by "HP".
df.sort_values(['Attack','HP'],ascending=[1,0])
#This tells Pandas the order for sorting each column.
#1 means True → sort in ascending order.
#0 means False → sort in descending order.
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# 230  213                  Shuckle      Bug      Rock   20      10      230
# ..   ...                      ...      ...       ...  ...     ...      ...
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Total']=df['Attack']+df['HP']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    269
# ...

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#: → means all rows.
#4:10 → means columns from index 4 up to 9 (Python excludes the last number).
#So this selects columns 4,5,6,7,8,9 from your DataFrame.
df['Total']=df.iloc[:,4:10].sum(axis=1)
df[['Total','HP','Defense']].head()
# Out:
#    Total  HP  Defense
# 0    318  45       49
# 1    405  60       63
# 2    525  80       83
# 3    625  80      123
# 4    309  39       43

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b956aab5-f0a2-40d2-9305-704704a20899" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b956aab5-f0a2-40d2-9305-704704a20899">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('pokemon_data.csv')

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df['Total']=df.iloc[:,4:10].sum(axis=1)
cols = list(df.columns)
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-19b127bd-138e-43df-8241-4f196de4a5b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19b127bd-138e-43df-8241-4f196de4a5b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('pokemon_data.csv')

# %%
df.loc[(df['Type 1']=='Rock') & (df['Type 2']=='Fairy')]
# Out:
#        #                 Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 773  703              Carbink   Rock  Fairy  50      50      150       50
# 795  719              Diancie   Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie   Rock  Fairy  50     160      110      160
#
#      Sp. Def  Speed  Generation  Legendary
# 773      150     50           6      False
# 795      150     50           6       True
# 796      110    110           6       True

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
df_new=df.loc[df['Name'].str.contains('Mega')]
df_new.count()
# Out:
# #             49
# Name          49
# Type 1        49
# Type 2        39
# HP            49
# Attack        49
# Defense       49
# Sp. Atk       49
# Sp. Def       49
# Speed         49
# Generation    49
# Legendary     49
# dtype: int64

# %%
df['Type 1'].str.contains('Fire|Grass', case=False, regex=True).sum()
# Out:
# np.int64(122)

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass', case=False, regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df['Name'].str.contains('^Pi[a-z]*',regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
df.loc[df['Name'].str.contains('pi[a-z]*',regex=True)]
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 13    10    Caterpie      Bug     NaN   45      30       35       20       20
# 42    37      Vulpix     Fire     NaN   38      41       40       50       65
# 76    70  Weepinbell    Grass  Poison   65      90       50       85       45
# 84    78    Rapidash     Fire     NaN   65     100       70       80       80
# 181  167    Spinarak      Bug  Poison   40      60       40       40       40
# 189  175      Togepi    Fairy     NaN   35      20       65       40       65
# 202  187      Hoppip    Grass  Flying   35      35       40       35       55
# 266  247     Pupitar     Rock  Ground   70      84       70       65       70
# 345  316      Gulpin   Poison     NaN   70      43       53       43       53
# 357  326     Grumpig  Psychic     NaN   80      45       65       90      110
# 358  327      Spinda   Normal     NaN   60      60       60       60       60
# ...

# %%
df.loc[df['Type 1']=='Fire','Legendary']=True
df.loc[1:11]
#IF TYPE 1 IS FIRE THEN LEGENDARY VALUE IS REPLACED BY TRUE
# Out:
#     #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1   2                    Ivysaur  Grass  Poison  60      62       63       80
# 2   3                   Venusaur  Grass  Poison  80      82       83      100
# 3   3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4   4                 Charmander   Fire     NaN  39      52       43       60
# 5   5                 Charmeleon   Fire     NaN  58      64       58       80
# 6   6                  Charizard   Fire  Flying  78      84       78      109
# 7   6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8   6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9   7                   Squirtle  Water     NaN  44      48       65       50
# 10  8                  Wartortle  Water     NaN  59      63       80       65
# 11  9                  Blastoise  Water     NaN  79      83      100       85
#
# ...

# %%
df.loc[df['Name']=='Pikachu']
# Out:
#      #     Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 30  25  Pikachu  Electric    NaN  35      55       40       50       50
#
#     Speed  Generation  Legendary
# 30     90           1      False

# %%
df.loc[df['HP']>60 ,['Generation','Legendary']]='TEST VALUE'
df.tail(10)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation   Legendary
# 790       40     55           6       False
# ...

# %%
df['Count']=1

# %%
df.groupby(['Type 1','Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64
